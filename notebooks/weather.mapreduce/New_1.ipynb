# %%
from mrjob.job import MRJob
import re
import pandas as pd
from sys import stderr
import sys,os
data_dir = '/home/ubuntu/UCSD_BigData/data/weather/'
home_dir='/home/ubuntu/UCSD_BigData/'
sys.path.append(home_dir+'/utils')
from create_job_flow import *

# %%
job_flow_id = create_job_flow()
# Out:
# credentials.csv AWS creds: chw124 AKIAIABXTKW7CDCCKGSQ
# an active key pair
# <boto.emr.emrobject.JobFlow object at 0x33d6e50>
#  no_script.yoavfreund.20140516.040032.370095 j-262J0JTFJIRLO WAITING

# %%
import gzip
import cPickle

f = open('valid_stations.txt', 'rb')
#f = open('ssss.txt', 'rb')
d = []
for line in f.readlines():
    data = re.compile(r"[\.\w-]+").findall(line)
    d.append(data)
header = ['station', 'weight']  
df = pd.DataFrame(d,columns=header)
df['weight'] = df['weight'].astype(float)
f = gzip.open('stations.pkl.gz', "rb")
pickleFile = cPickle.Unpickler(f)
station_info = pickleFile.load()[['latitude','longitude','elevation']]
Djoined = df.join(station_info, on='station')

Djoined.head()
DD = Djoined.head()

# %%
DD
# Out:
#        station  weight  latitude  longitude  elevation
# 0  AJ000037907      16    39.600    47.1500      439.0
# 1  AQC00914873       9   -14.350  -170.7667       14.9
# 2  AR000087270      44   -29.183   -59.7000       53.0
# 3  AR000087344      46   -31.317   -64.2170      489.0
# 4  AR000087418      45   -32.833   -68.7830      704.0
#
# [5 rows x 5 columns]

# %%
from __future__ import division
import pandas as pd
from mrjob.job import MRJob
import random

labels = np.arange(10000)
random.shuffle(labels)
regions = labels
count = 0

class QuadTree:
    def __init__(self, stations, depth, bounding_rect, maxIt):
        global count
        self.nw = self.ne = self.se = self.sw = None
        self.maxIt = maxIt
        self.depth = depth
        cum_sum = stations.weight.cumsum()
        if cum_sum.iloc[-1] <= self.maxIt:
            print '-----Leaf-----', cum_sum.iloc[-1], '----Nodes----', len(stations)
            Djoined.loc[stations.index,'label']= regions[count]
            #DD.loc[stations.index,'label']= regions[self.depth]
            self.region = regions[count]
            count += 1
            self.leaf = True
            return

        self.bounding_rect = bounding_rect
        l, t, r, b = bounding_rect
        cx = self.cx = ( l + r ) * 0.5 
        cy = self.cy = ( t + b ) * 0.5 

        self.items = []
        nw_items = []
        ne_items = []
        se_items = []
        sw_items = []

        for item in stations.index:
            item_x = stations.loc[item, 'latitude']
            item_y = stations.loc[item, 'longitude']
            
            in_nw = item_x <= cx and item_y >  cy  
            in_ne = item_x >  cx and item_y >= cy
            in_sw = item_x <= cx and item_y <  cy  
            in_se = item_x >  cx and item_y <= cy
            
            if   in_nw: nw_items.append(item)
            elif in_ne: ne_items.append(item)
            elif in_sw: sw_items.append(item)
            elif in_se: se_items.append(item)

        if nw_items:
            self.nw = QuadTree(stations.loc[nw_items], depth+1, (l, t, cx, cy),maxIt)
        if ne_items:
            self.ne = QuadTree(stations.loc[ne_items], depth+1, (cx, t, r, cy),maxIt)
        if se_items:
            self.se = QuadTree(stations.loc[se_items], depth+1, (cx, cy, r, b),maxIt)
        if sw_items:
            self.sw = QuadTree(stations.loc[sw_items], depth+1, (l, cy, cx, b),maxIt)

# %%
QQ = QuadTree(Djoined, 0, [-90, 180, 90, -180], 5000)
# Out:
# -----Leaf----- 219.0 ----Nodes---- 6
# -----Leaf-----
#  270.0 ----Nodes---- 6
# -----Leaf-----
#  271.0 ----Nodes---- 14
# -----Leaf----- 996.0 ----Nodes---- 46
# -----Leaf----- 1132.0 ----Nodes---- 40
# -----Leaf----- 2919.0 ----Nodes---- 114
# -----Leaf----- 3417.0 ----Nodes---- 114
# -----Leaf----- 951.0 ----Nodes---- 26
# -----Leaf----- 1899.0 ----Nodes---- 63
# -----Leaf-----
#  2232.0 ----Nodes---- 99
# -----Leaf----- 4650.0 ----Nodes---- 224
# -----Leaf-----
#  3110.0 ----Nodes---- 145
# -----Leaf----- 1591.0 ----Nodes---- 64
# -----Leaf----- 2305.0 ----Nodes---- 90
# -----Leaf----- 265.0 ----Nodes---- 8
# -----Leaf----- 743.0 ----Nodes---- 39
# -----Leaf----- 3904.0 ----Nodes---- 140
# -----Leaf----- 3587.0 ----Nodes---- 167
# -----Leaf-----
#  962.0 ----Nodes---- 27
# -----Leaf-----
#  670.0 ----Nodes---- 25
# -----Leaf----- 512.0 ----Nodes---- 21
# -----Leaf----- 873.0 ----Nodes---- 37
# -----Leaf----- 4062.0 ----Nodes---- 123
# -----Leaf----- 3260.0 ----Nodes---- 139
# -----Leaf----- 159.0 ----Nodes---- 4
# -----Leaf-----
#  930.0 ----Nodes---- 49
# -----Leaf----- 4553.0 ----Nodes---- 117
# -----Leaf-----
#  3222.0 ----Nodes---- 76
# -----Leaf----- 4728.0 ----Nodes---- 111
# -----Leaf----- 2009.0 ----Nodes---- 36
# -----Leaf----- 2735.0 ----Nodes---- 52
# -----Leaf----- 3723.0 ----Nodes---- 131
# -----Leaf-----
#  609.0 ----Nodes---- 15
# -----Leaf----- 1184.0 ----Nodes---- 21
# -----Leaf----- 1544.0 ----Nodes---- 29
# -----Leaf----- 2728.0 ----Nodes---- 58
# -----Leaf----- 587.0 ----Nodes---- 13
# -----Leaf----- 1034.0 ----Nodes---- 16
# -----Leaf-----
#  4305.0 ----Nodes---- 95
# -----Leaf----- 1900.0 ----Nodes---- 37
# -----Leaf----- 1472.0 ----Nodes---- 29
# -----Leaf----- 3412.0 ----Nodes---- 74
# -----Leaf-----
#  3792.0 ----Nodes---- 101
# -----Leaf----- 1982.0 ----Nodes---- 38
# -----Leaf----- 3691.0 ----Nodes---- 73
# -----Leaf----- 4711.0 ----Nodes---- 108
# -----Leaf----- 1171.0 ----Nodes---- 21
# -----Leaf----- 2398.0 ----Nodes---- 58
# -----Leaf-----
#  2198.0 ----Nodes---- 77
# -----Leaf----- 1826.0 ----Nodes---- 48
# -----Leaf----- 1770.0 ----Nodes---- 65
# -----Leaf----- 2506.0 ----Nodes---- 113
# -----Leaf----- 4700.0 ----Nodes---- 112
# -----Leaf-----
#  1436.0 ----Nodes---- 37
# -----Leaf----- 1154.0 ----Nodes---- 36
# -----Leaf----- 996.0 ----Nodes---- 28
# -----Leaf----- 2470.0 ----Nodes---- 66
# -----Leaf-----
#  3522.0 ----Nodes---- 59
# -----Leaf----- 2442.0 ----Nodes---- 36
# -----Leaf----- 3783.0 ----Nodes---- 100
# -----Leaf----- 4652.0 ----Nodes---- 85
# -----Leaf-----
#  1283.0 ----Nodes---- 46
# -----Leaf-----
#  708.0 ----Nodes---- 35
# -----Leaf----- 2078.0 ----Nodes---- 52
# -----Leaf----- 2710.0 ----Nodes---- 60
# -----Leaf----- 341.0 ----Nodes---- 12
# -----Leaf-----
#  519.0 ----Nodes---- 17
# -----Leaf----- 3207.0 ----Nodes---- 75
# -----Leaf----- 3842.0 ----Nodes---- 64
# -----Leaf----- 253.0 ----Nodes---- 6
# -----Leaf----- 2974.0 ----Nodes---- 109
# -----Leaf-----
#  1405.0 ----Nodes---- 54
# -----Leaf-----
#  691.0 ----Nodes---- 20
# -----Leaf----- 4624.0 ----Nodes---- 98
# -----Leaf----- 27.0 ----Nodes---- 2
# -----Leaf-----
#  76.0 ----Nodes---- 2
# -----Leaf----- 2259.0 ----Nodes---- 68
# -----Leaf-----
#  364.0 ----Nodes---- 16
# -----Leaf----- 1676.0 ----Nodes---- 46
# -----Leaf-----
#  920.0 ----Nodes---- 26
# -----Leaf----- 2603.0 ----Nodes---- 95
# -----Leaf----- 971.0 ----Nodes---- 34
# -----Leaf----- 1056.0 ----Nodes---- 34
# -----Leaf----- 2708.0 ----Nodes---- 101
# -----Leaf----- 4444.0 ----Nodes---- 134
# -----Leaf-----
#  4400.0 ----Nodes---- 170
# -----Leaf-----
#  1.0 ----Nodes---- 1
# -----Leaf----- 1845.0 ----Nodes---- 61
# -----Leaf----- 3736.0 ----Nodes---- 160
# -----Leaf-----
#  2228.0 ----Nodes---- 78
# -----Leaf----- 937.0 ----Nodes---- 35
# -----Leaf----- 895.0 ----Nodes---- 40
# -----Leaf----- 1445.0 ----Nodes---- 63
# -----Leaf-----
#  3829.0 ----Nodes---- 141
# -----Leaf----- 3131.0 ----Nodes---- 90
# -----Leaf----- 2365.0 ----Nodes---- 90
# -----Leaf----- 3328.0 ----Nodes---- 100
# -----Leaf-----
#  413.0 ----Nodes---- 8
# -----Leaf----- 1659.0 ----Nodes---- 46
# -----Leaf----- 1785.0 ----Nodes---- 48
# -----Leaf----- 2134.0 ----Nodes---- 67
# -----Leaf-----
#  1917.0 ----Nodes---- 62
# -----Leaf----- 1243.0 ----Nodes---- 48
# -----Leaf----- 617.0 ----Nodes---- 23
# -----Leaf----- 1600.0 ----Nodes---- 43
# -----Leaf----- 3084.0 ----Nodes---- 122
# -----Leaf----- 4876.0 ----Nodes---- 172
# -----Leaf-----
#  1615.0 ----Nodes---- 52
# -----Leaf----- 1338.0 ----Nodes---- 44
# -----Leaf----- 1190.0 ----Nodes---- 35
# -----Leaf----- 996.0 ----Nodes---- 28
# -----Leaf----- 3089.0 ----Nodes---- 101
# -----Leaf----- 3652.0 ----Nodes---- 94
# -----Leaf----- 4453.0 ----Nodes---- 110
# -----Leaf-----
#  4311.0 ----Nodes---- 140
# -----Leaf----- 4270.0 ----Nodes---- 175
# -----Leaf----- 1544.0 ----Nodes---- 49
# -----Leaf----- 3090.0 ----Nodes---- 130
# -----Leaf-----
#  2366.0 ----Nodes---- 66
# -----Leaf----- 2073.0 ----Nodes---- 60
# -----Leaf----- 2958.0 ----Nodes---- 67
# -----Leaf----- 3466.0 ----Nodes---- 101
# -----Leaf-----
#  3520.0 ----Nodes---- 87
# -----Leaf----- 3336.0 ----Nodes---- 89
# -----Leaf----- 3160.0 ----Nodes---- 80
# -----Leaf----- 2717.0 ----Nodes---- 73
# -----Leaf-----
#  3483.0 ----Nodes---- 86
# -----Leaf----- 3651.0 ----Nodes---- 99
# -----Leaf----- 4757.0 ----Nodes---- 144
# -----Leaf----- 3786.0 ----Nodes---- 117
# -----Leaf-----
#  3544.0 ----Nodes---- 94
# -----Leaf----- 4249.0 ----Nodes---- 136
# -----Leaf----- 3107.0 ----Nodes---- 104
# -----Leaf----- 2342.0 ----Nodes---- 107
# -----Leaf-----
#  2665.0 ----Nodes---- 81
# -----Leaf----- 3800.0 ----Nodes---- 101
# -----Leaf----- 3139.0 ----Nodes---- 70
# -----Leaf----- 3216.0 ----Nodes---- 89
# -----Leaf-----
#  2802.0 ----Nodes---- 81
# -----Leaf----- 3355.0 ----Nodes---- 102
# -----Leaf----- 3061.0 ----Nodes---- 74
# -----Leaf----- 2693.0 ----Nodes---- 68
# -----Leaf-----
#  58.0 ----Nodes---- 4
# -----Leaf-----
#  1005.0 ----Nodes---- 31
# -----Leaf----- 554.0 ----Nodes---- 15
# -----Leaf----- 2461.0 ----Nodes---- 71
# -----Leaf----- 1117.0 ----Nodes---- 28
# -----Leaf-----
#  578.0 ----Nodes---- 20
# -----Leaf----- 2064.0 ----Nodes---- 58
# -----Leaf----- 2633.0 ----Nodes---- 76
# -----Leaf----- 2277.0 ----Nodes---- 71
# -----Leaf-----
#  2112.0 ----Nodes---- 65
# -----Leaf----- 3007.0 ----Nodes---- 79
# -----Leaf----- 2383.0 ----Nodes---- 60
# -----Leaf----- 1769.0 ----Nodes---- 48
# -----Leaf----- 3727.0 ----Nodes---- 122
# -----Leaf-----
#  424.0 ----Nodes---- 17
# -----Leaf----- 4760.0 ----Nodes---- 148
# -----Leaf----- 4268.0 ----Nodes---- 141
# -----Leaf-----
#  2152.0 ----Nodes---- 34
# -----Leaf----- 153.0 ----Nodes---- 3
# -----Leaf----- 899.0 ----Nodes---- 39
# -----Leaf-----
#  2333.0 ----Nodes---- 109
# -----Leaf----- 262.0 ----Nodes---- 14
# -----Leaf----- 741.0 ----Nodes---- 30
# -----Leaf-----
#  1230.0 ----Nodes---- 51
# -----Leaf----- 1180.0 ----Nodes---- 43
# -----Leaf----- 1991.0 ----Nodes---- 76
# -----Leaf-----
#  2034.0 ----Nodes---- 83
# -----Leaf----- 451.0 ----Nodes---- 17
# -----Leaf----- 1070.0 ----Nodes---- 37
# -----Leaf----- 2073.0 ----Nodes---- 70
# -----Leaf----- 308.0 ----Nodes---- 18
# -----Leaf----- 472.0 ----Nodes---- 16
# -----Leaf-----
#  1246.0 ----Nodes---- 50
# -----Leaf----- 1697.0 ----Nodes---- 58
# -----Leaf----- 2517.0 ----Nodes---- 85
# -----Leaf----- 4160.0 ----Nodes---- 120
# -----Leaf----- 2936.0 ----Nodes---- 90
# -----Leaf----- 994.0 ----Nodes---- 40
# -----Leaf-----
#  4525.0 ----Nodes---- 131
# -----Leaf----- 514.0 ----Nodes---- 17
# -----Leaf----- 241.0 ----Nodes---- 9
# -----Leaf----- 1558.0 ----Nodes---- 54
# -----Leaf----- 294.0 ----Nodes---- 9
# -----Leaf----- 366.0 ----Nodes---- 13
# -----Leaf-----
#  3299.0 ----Nodes---- 100
# -----Leaf----- 1174.0 ----Nodes---- 39
# -----Leaf----- 1430.0 ----Nodes---- 63
# -----Leaf-----
#  1938.0 ----Nodes---- 62
# -----Leaf----- 494.0 ----Nodes---- 13
# -----Leaf----- 1064.0 ----Nodes---- 42
# -----Leaf----- 2186.0 ----Nodes---- 58
# -----Leaf-----
#  2145.0 ----Nodes---- 48
# -----Leaf----- 1925.0 ----Nodes---- 56
# -----Leaf----- 1539.0 ----Nodes---- 39
# -----Leaf----- 2064.0 ----Nodes---- 53
# -----Leaf----- 2436.0 ----Nodes---- 85
# -----Leaf-----
#  2070.0 ----Nodes---- 45
# -----Leaf----- 1717.0 ----Nodes---- 67
# -----Leaf----- 1866.0 ----Nodes---- 59
# -----Leaf----- 2113.0 ----Nodes---- 51
# -----Leaf-----
#  2408.0 ----Nodes---- 48
# -----Leaf----- 1830.0 ----Nodes---- 38
# -----Leaf----- 2017.0 ----Nodes---- 41
# -----Leaf----- 1759.0 ----Nodes---- 38
# -----Leaf----- 2174.0 ----Nodes---- 92
# -----Leaf-----
#  4211.0 ----Nodes---- 143
# -----Leaf----- 661.0 ----Nodes---- 24
# -----Leaf----- 1170.0 ----Nodes---- 54
# -----Leaf----- 4021.0 ----Nodes---- 167
# -----Leaf-----
#  1643.0 ----Nodes---- 42
# -----Leaf----- 1806.0 ----Nodes---- 46
# -----Leaf----- 1423.0 ----Nodes---- 35
# -----Leaf----- 1266.0 ----Nodes---- 42
# -----Leaf-----
#  1889.0 ----Nodes---- 40
# -----Leaf----- 1445.0 ----Nodes---- 40
# -----Leaf----- 1564.0 ----Nodes---- 54
# -----Leaf----- 1539.0 ----Nodes---- 40
# -----Leaf-----
#  1378.0 ----Nodes---- 45
# -----Leaf----- 1264.0 ----Nodes---- 41
# -----Leaf----- 1051.0 ----Nodes---- 40
# -----Leaf----- 2080.0 ----Nodes---- 56
# -----Leaf-----
#  1793.0 ----Nodes---- 46
# -----Leaf----- 1488.0 ----Nodes---- 56
# -----Leaf----- 2531.0 ----Nodes---- 89
# -----Leaf----- 2490.0 ----Nodes---- 87
# -----Leaf----- 1511.0 ----Nodes---- 81
# -----Leaf----- 3752.0 ----Nodes---- 154
# -----Leaf-----
#  2188.0 ----Nodes---- 75
# -----Leaf----- 2236.0 ----Nodes---- 74
# -----Leaf----- 2906.0 ----Nodes---- 88
# -----Leaf----- 2404.0 ----Nodes---- 87
# -----Leaf-----
#  2318.0 ----Nodes---- 88
# -----Leaf----- 1715.0 ----Nodes---- 83
# -----Leaf----- 1370.0 ----Nodes---- 47
# -----Leaf----- 2551.0 ----Nodes---- 85
# -----Leaf-----
#  2399.0 ----Nodes---- 86
# -----Leaf----- 2295.0 ----Nodes---- 89
# -----Leaf----- 2317.0 ----Nodes---- 94
# -----Leaf-----
#  620.0 ----Nodes---- 17
# -----Leaf----- 1125.0 ----Nodes---- 36
# -----Leaf----- 2361.0 ----Nodes---- 74
# -----Leaf----- 1199.0 ----Nodes---- 40
# -----Leaf-----
#  3296.0 ----Nodes---- 90
# -----Leaf----- 2864.0 ----Nodes---- 72
# -----Leaf----- 4174.0 ----Nodes---- 125
# -----Leaf----- 4438.0 ----Nodes---- 143
# -----Leaf-----
#  4384.0 ----Nodes---- 193
# -----Leaf----- 2357.0 ----Nodes---- 111
# -----Leaf----- 1477.0 ----Nodes---- 71
# -----Leaf----- 3283.0 ----Nodes---- 135
# -----Leaf----- 4416.0 ----Nodes---- 170
# -----Leaf----- 4487.0 ----Nodes---- 164
# -----Leaf----- 1091.0 ----Nodes---- 51
# -----Leaf----- 900.0 ----Nodes---- 48
# -----Leaf-----
#  1915.0 ----Nodes---- 87
# -----Leaf----- 1984.0 ----Nodes---- 103
# -----Leaf----- 2665.0 ----Nodes---- 151
# -----Leaf----- 3471.0 ----Nodes---- 207
# -----Leaf----- 1763.0 ----Nodes---- 92
# -----Leaf----- 321.0 ----Nodes---- 21
# -----Leaf-----
#  3571.0 ----Nodes---- 96
# -----Leaf-----
#  3531.0 ----Nodes---- 100
# -----Leaf-----
#  70.0 ----Nodes---- 4
# -----Leaf----- 3571.0 ----Nodes---- 90
# -----Leaf----- 1947.0 ----Nodes---- 64
# -----Leaf----- 457.0 ----Nodes---- 19
# -----Leaf-----
#  2624.0 ----Nodes---- 79
# -----Leaf----- 2572.0 ----Nodes---- 67
# -----Leaf----- 2492.0 ----Nodes---- 72
# -----Leaf----- 1986.0 ----Nodes---- 75
# -----Leaf-----
#  2169.0 ----Nodes---- 50
# -----Leaf----- 2628.0 ----Nodes---- 81
# -----Leaf----- 1928.0 ----Nodes---- 46
# -----Leaf----- 1380.0 ----Nodes---- 40
# -----Leaf-----
#  1905.0 ----Nodes---- 54
# -----Leaf----- 2500.0 ----Nodes---- 67
# -----Leaf----- 1360.0 ----Nodes---- 39
# -----Leaf----- 1649.0 ----Nodes---- 46
# -----Leaf-----
#  1668.0 ----Nodes---- 54
# -----Leaf-----
#  1204.0 ----Nodes---- 33
# -----Leaf----- 1303.0 ----Nodes---- 33
# -----Leaf----- 2022.0 ----Nodes---- 54
# -----Leaf----- 1166.0 ----Nodes---- 42
# -----Leaf-----
#  1285.0 ----Nodes---- 34
# -----Leaf----- 2021.0 ----Nodes---- 63
# -----Leaf----- 3189.0 ----Nodes---- 100
# -----Leaf----- 2170.0 ----Nodes---- 72
# -----Leaf----- 627.0 ----Nodes---- 17
# -----Leaf----- 2203.0 ----Nodes---- 51
# -----Leaf-----
#  2541.0 ----Nodes---- 49
# -----Leaf----- 2287.0 ----Nodes---- 58
# -----Leaf----- 3238.0 ----Nodes---- 76
# -----Leaf----- 2565.0 ----Nodes---- 65
# -----Leaf-----
#  2402.0 ----Nodes---- 67
# -----Leaf----- 2712.0 ----Nodes---- 71
# -----Leaf----- 2930.0 ----Nodes---- 81
# -----Leaf----- 2756.0 ----Nodes---- 71
# -----Leaf-----
#  2761.0 ----Nodes---- 60
# -----Leaf----- 2789.0 ----Nodes---- 66
# -----Leaf----- 1975.0 ----Nodes---- 46
# -----Leaf----- 2080.0 ----Nodes---- 43
# -----Leaf-----
#  2530.0 ----Nodes---- 77
# -----Leaf----- 2922.0 ----Nodes---- 79
# -----Leaf----- 2159.0 ----Nodes---- 57
# -----Leaf----- 1989.0 ----Nodes---- 46
# -----Leaf-----
#  2676.0 ----Nodes---- 53
# -----Leaf----- 3503.0 ----Nodes---- 60
# -----Leaf----- 3241.0 ----Nodes---- 58
# -----Leaf----- 3136.0 ----Nodes---- 69
# -----Leaf-----
#  3080.0 ----Nodes---- 58
# -----Leaf----- 3090.0 ----Nodes---- 71
# -----Leaf----- 2760.0 ----Nodes---- 78
# -----Leaf----- 2858.0 ----Nodes---- 42
# -----Leaf-----
#  2904.0 ----Nodes---- 46
# -----Leaf----- 2468.0 ----Nodes---- 52
# -----Leaf----- 1856.0 ----Nodes---- 46
# -----Leaf----- 1807.0 ----Nodes---- 36
# -----Leaf-----
#  2762.0 ----Nodes---- 64
# -----Leaf----- 3663.0 ----Nodes---- 76
# -----Leaf----- 1939.0 ----Nodes---- 47
# -----Leaf----- 2785.0 ----Nodes---- 57
# -----Leaf-----
#  1474.0 ----Nodes---- 34
# -----Leaf----- 2151.0 ----Nodes---- 57
# -----Leaf----- 2212.0 ----Nodes---- 76
# -----Leaf----- 4210.0 ----Nodes---- 137
# -----Leaf-----
#  1817.0 ----Nodes---- 48
# -----Leaf----- 2327.0 ----Nodes---- 71
# -----Leaf----- 1868.0 ----Nodes---- 54
# -----Leaf----- 1541.0 ----Nodes---- 61
# -----Leaf-----
#  1270.0 ----Nodes---- 49
# -----Leaf----- 2560.0 ----Nodes---- 88
# -----Leaf----- 2855.0 ----Nodes---- 94
# -----Leaf----- 2763.0 ----Nodes---- 88
# -----Leaf-----
#  2139.0 ----Nodes---- 74
# -----Leaf----- 1063.0 ----Nodes---- 43
# -----Leaf----- 3768.0 ----Nodes---- 116
# -----Leaf----- 4777.0 ----Nodes---- 167
# -----Leaf-----
#  1616.0 ----Nodes---- 45
# -----Leaf----- 1675.0 ----Nodes---- 56
# -----Leaf----- 3013.0 ----Nodes---- 97
# -----Leaf----- 1853.0 ----Nodes---- 64
# -----Leaf-----
#  1503.0 ----Nodes---- 48
# -----Leaf----- 2266.0 ----Nodes---- 53
# -----Leaf----- 2459.0 ----Nodes---- 88
# -----Leaf----- 2649.0 ----Nodes---- 79
# -----Leaf-----
#  3136.0 ----Nodes---- 94
# -----Leaf----- 2785.0 ----Nodes---- 84
# -----Leaf----- 2461.0 ----Nodes---- 76
# -----Leaf----- 1706.0 ----Nodes---- 63
# -----Leaf-----
#  1724.0 ----Nodes---- 55
# -----Leaf----- 1636.0 ----Nodes---- 58
# -----Leaf----- 1251.0 ----Nodes---- 52
# -----Leaf----- 3298.0 ----Nodes---- 97
# -----Leaf-----
#  1300.0 ----Nodes---- 39
# -----Leaf----- 1267.0 ----Nodes---- 49
# -----Leaf----- 1141.0 ----Nodes---- 40
# -----Leaf----- 3461.0 ----Nodes---- 117
# -----Leaf-----
#  2227.0 ----Nodes---- 75
# -----Leaf----- 1497.0 ----Nodes---- 53
# -----Leaf----- 849.0 ----Nodes---- 42
# -----Leaf----- 640.0 ----Nodes---- 27
# -----Leaf-----
#  2910.0 ----Nodes---- 97
# -----Leaf----- 3568.0 ----Nodes---- 130
# -----Leaf----- 4640.0 ----Nodes---- 119
# -----Leaf----- 3761.0 ----Nodes---- 104
# -----Leaf-----
#  3255.0 ----Nodes---- 117
# -----Leaf----- 2796.0 ----Nodes---- 75
# -----Leaf----- 375.0 ----Nodes---- 16
# -----Leaf-----
#  1061.0 ----Nodes---- 46
# -----Leaf----- 1416.0 ----Nodes---- 61
# -----Leaf----- 1373.0 ----Nodes---- 54
# -----Leaf----- 1263.0 ----Nodes---- 56
# -----Leaf-----
#  2924.0 ----Nodes---- 75
# -----Leaf----- 2002.0 ----Nodes---- 85
# -----Leaf----- 3541.0 ----Nodes---- 94
# -----Leaf----- 1788.0 ----Nodes---- 58
# -----Leaf-----
#  1780.0 ----Nodes---- 66
# -----Leaf----- 2121.0 ----Nodes---- 80
# -----Leaf----- 4086.0 ----Nodes---- 130
# -----Leaf----- 3152.0 ----Nodes---- 112
# -----Leaf-----
#  2170.0 ----Nodes---- 70
# -----Leaf----- 1347.0 ----Nodes---- 46
# -----Leaf----- 2420.0 ----Nodes---- 89
# -----Leaf----- 3028.0 ----Nodes---- 96
# -----Leaf----- 2256.0 ----Nodes---- 76
# -----Leaf-----
#  64.0 ----Nodes---- 2
# -----Leaf-----
#  177.0 ----Nodes---- 4
# -----Leaf-----
#  120.0 ----Nodes---- 3
# -----Leaf----- 1523.0 ----Nodes---- 44
# -----Leaf----- 3829.0 ----Nodes---- 114
# -----Leaf----- 101.0 ----Nodes---- 2
# -----Leaf----- 225.0 ----Nodes---- 7
# -----Leaf----- 102.0 ----Nodes---- 4
# -----Leaf-----
#  3432.0 ----Nodes---- 144
# -----Leaf----- 2333.0 ----Nodes---- 112
# -----Leaf----- 2.0 ----Nodes---- 1
# -----Leaf----- 2419.0 ----Nodes---- 111

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

stations = station_info
lons=Djoined.ix[:,'longitude'].values
lats=Djoined.ix[:,'latitude'].values
ll=len(lons)
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
select=(lons>lonmin) * (lons<lonmax)*(lats>latsmin)*(lats<latsmax)


plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,\
            llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
#m.fillcontinents(color='coral',lake_color='aqua')

parallels = np.arange(-80,81,10.)
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(10.,351.,20.)
m.drawmeridians(meridians,labels=[True,False,False,True])

#m.drawmapboundary(fill_color='aqua')

colors = Djoined['label'].tolist()
x, y = m(lons,lats)
col = m.scatter(x,y,c=colors, marker='o',lw=0,zorder=2,s=3)
colbar = m.colorbar(col, location='right', pad = "5%")
plt.title('weather stations')
plt.show()
