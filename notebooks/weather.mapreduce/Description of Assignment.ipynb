# %% [markdown]
# In this assignment you are asked to analyze the complete weather dataset.
#
#
# ### Possible directions, from the general to the specific ###
# The following questions are meant as starting points, you are encouraged to go beyond them.
# Remember to describe your work, with words and figures, so that your reviewers, and anybody else, would be able to follow.

# %% [markdown]
# ### Coverage and Cleanup ###
# While the weather data collection is large, its coverage is very uneven. Many active stations exist in the USA and in India, while there are relatively very few in Africa.
#
# In this section our goal is to characterize the coverage of the data and to clean it based on the coverage.
# By *coverage* we mean to identify the geographic locations, times and types of measurements for which we have a lot of data and
# the parts for which we have only little. By establishing the coverage we identify the types of statistical queries that we can make and the types for which we have too little data.
#
# **Heirarchical representation:** When we want to represent sparse data, it is often useful to create a hierarchy:
#
# 1. **Can we ignore stations with no temperature recordings?** It seems reasonable to assume that any station that has published useful measurements has at least published minimum and maximum termperatures. Can you confirm or deny this?
# 1. **Geographic baseline:** Some parts of the world have a lot of stations and measurements, some very few. Create a hierarchical representation of this data.
# 1. **Measurement Types ** There is a large number of measurements, but most of them occur only rarely. Can you compute and describe:
#   1. How many times does each type of measurement occur in the database.
#   1. What fraction of the entries are not empty?

# %%
from mrjob.job import MRJob
import re
import pandas as pd
from sys import stderr
import sys,os
data_dir = '/home/ubuntu/UCSD_BigData/data/weather/'
home_dir='/home/ubuntu/UCSD_BigData/'
sys.path.append(home_dir+'/utils')
from create_job_flow import *

# %%
job_flow_id = create_job_flow()
# Out:
# credentials.csv AWS creds: chw124 AKIAIABXTKW7CDCCKGSQ
# an active key pair
# ...
#  no_script.yoavfreund.20140516.040032.370095 j-262J0JTFJIRLO WAITING
# <boto.emr.emrobject.JobFlow object at 0x4f23750> no_script.yoavfreund.20140517.080731.371759 j-1RE8D7HBISOI0 WAITING

# %% [raw]
# Valid Station
#
# # mapper:
#     data => [station, year], [data]
# # reducer1:
# [station, year], vector[data] => station, 1/0
# 1) if len(vector[data]) >= 2: OK
# 2) if data1 and data2 data1[i]!= '' && data2[i] != '': OK
#
# # reducer2:
# station, 1/0 => station
# 1) len(1)/len(1+0) > 50% : OK

# %%
# %%writefile test.py
from __future__ import division
from mrjob.job import MRJob

class ValidStation(MRJob):
    def mapper1(self, _, line):
        elements = line.split(',')
        if elements[1] == 'TMIN' or elements[1] == 'TMAX':
            yield (elements[0], elements[2]), elements[3:]

    def reducer1(self, pair, vectors):
        vectors = list(vectors)
        if len(vectors) < 2:
            yield pair[0], 0
        else:
            day_count = 0 
            for i in range(len(vectors[0])):
                if vectors[0][i] != '' and vectors[1][i] != '': 
                    day_count += 1
            if day_count / len(vectors[0]) < 0.5:
                yield pair[0], 0
            else:
                yield pair[0], 1
    
    def reducer2(self, station, is_valid):
        sum_valid = sum(is_valid)
        if sum_valid != 0:
            yield station, sum_valid
    
    def steps(self):
        return [self.mr(mapper=self.mapper1, reducer=self.reducer1),
                self.mr(reducer=self.reducer2)]

if __name__ == '__main__':
    ValidStation.run()
# Out:
# Overwriting test.py

# %%
local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
# !python test.py $local_data
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/test.ubuntu.20140522.172715.748130
# writing to /tmp/test.ubuntu.20140522.172715.748130/step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /tmp/test.ubuntu.20140522.172715.748130/step-0-mapper-sorted
# > sort /tmp/test.ubuntu.20140522.172715.748130/step-0-mapper_part-00000
# writing to /tmp/test.ubuntu.20140522.172715.748130/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /tmp/test.ubuntu.20140522.172715.748130/step-1-mapper_part-00000
# Counters from step 2:
#   (no counters found)
# writing to /tmp/test.ubuntu.20140522.172715.748130/step-1-mapper-sorted
# > sort /tmp/test.ubuntu.20140522.172715.748130/step-1-mapper_part-00000
# writing to /tmp/test.ubuntu.20140522.172715.748130/step-1-reducer_part-00000
# Counters from step 2:
#   (no counters found)
# ...

# %%
# !python test.py -r emr --emr-job-flow-id  $job_flow_id < $local_data
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/test.ubuntu.20140521.222656.656460
# reading from STDIN
# Copying non-input files into s3://chuan.bucket/scratch/test.ubuntu.20140521.222656.656460/files/
# Adding our job to existing job flow j-1RE8D7HBISOI0
# Job launched 30.7s ago, status RUNNING: Running step (test.ubuntu.20140521.222656.656460: Step 1 of 2)
# Job launched 61.3s ago, status RUNNING: Running step (test.ubuntu.20140521.222656.656460: Step 1 of 2)
# Job launched 92.0s ago, status RUNNING: Running step (test.ubuntu.20140521.222656.656460: Step 1 of 2)
# Job launched 122.7s ago, status RUNNING: Running step (test.ubuntu.20140521.222656.656460: Step 2 of 2)
# Job launched 153.4s ago, status RUNNING: Running step (test.ubuntu.20140521.222656.656460: Step 2 of 2)
# Job completed.
# Running time was 142.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# ...

# %%
# !python test.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv > valid_stations.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/test.ubuntu.20140521.031657.472174
# Copying non-input files into s3://yoav.hadoop/scratch/test.ubuntu.20140521.031657.472174/files/
# Adding our job to existing job flow j-1RE8D7HBISOI0
# Job launched 30.5s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 1 of 2)
# Job launched 62.1s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 1 of 2)
# Job launched 92.5s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 1 of 2)
# Job launched 123.0s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 1 of 2)
# Job launched 153.5s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 1 of 2)
# Job launched 183.9s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 1 of 2)
# Job launched 214.4s ago, status RUNNING: Running step (test.ubuntu.20140521.031657.472174: Step 2 of 2)
# ...

# %%
Data Partition

Node:
    0 0 is latitude 1 is longitude
    1 latitude
    2 longitude
    3 isleaf
    4 depth

# %%
import gzip
import cPickle

f = open('valid_stations.txt', 'rb')
#f = open('ssss.txt', 'rb')
d = []
for line in f.readlines():
    data = re.compile(r"[\.\w-]+").findall(line)
    d.append(data)
header = ['station', 'weight']  
df = pd.DataFrame(d,columns=header)
df['weight'] = df['weight'].astype(float)
f = gzip.open('stations.pkl.gz', "rb")
pickleFile = cPickle.Unpickler(f)
station_info = pickleFile.load()[['latitude','longitude','elevation']]
Djoined = df.join(station_info, on='station')

Djoined.head()
DD = Djoined.head()

# %%
from __future__ import division
import pandas as pd
from mrjob.job import MRJob
import random

class Node:
    def __init__(self,la,lo,il,n,l,r):
        self.latitude  = la
        self.longitude = lo
        self.isleaf = il
        self.num = n
        self.left = l
        self.right = r
    def __str__(self):
        if self == None:
            print 'None'
        else:
            print 'Is Leaf: ', self.isleaf
            print 'latitude:', self.latitude
            print 'longitude', self.longitude
            print 'left'
            if self.left.isleaf == False: print self.left
            else: print 'Leaf'
            print 'right'
            if self.right.isleaf == False: print self.right
            else: print 'Leaf'
        print '!!!!!!'

class KDtree:
    def __init__(self, bincap, stations):
        tmp = np.arange(10000)
        random.shuffle(tmp)
        self.region = tmp
        self.count = 0
        self.bincap = bincap
        self.root = self.creat_tree(stations)
    
    def creat_tree(self, stations, depth=0):
        cum_sum = stations.weight.cumsum()
        if cum_sum.iloc[-1] <= self.bincap:
            print '-----Leaf-----', cum_sum.iloc[-1], '----Nodes----', len(stations)
            self.count += 1
            Djoined.loc[stations.index,'label']=self.region[self.count]
            return Node(None,None,True,self.region[self.count],None,None)
                      
        isLa = False
        isLo = False
        if depth % 2 == 0:
            isLa = True
            stations.sort('latitude',ascending=True,inplace=True)
        else:
            isLo = True
            stations.sort('longitude',ascending=True,inplace=True)

        median = 0 
        cum_sum = stations.weight.cumsum()
        for i in range(len(cum_sum)):
            if cum_sum.iloc[i] >= cum_sum.iloc[-1] / 2:
                median = i 
                break    
        if median == len(cum_sum)-1:
            median -= 1
            
        if isLa == True:    
            return Node(stations.iloc[median]['latitude']-0.00001,
                        None, False, None,
                        self.creat_tree(stations[:median+1],depth+1),
                        self.creat_tree(stations[median+1:],depth+1))
        elif isLo == True:
            return Node(stations.iloc[median]['longitude']-0.00001,
                        None, False, None,
                        self.creat_tree(stations[:median+1],depth+1),
                        self.creat_tree(stations[median+1:],depth+1))
    def trace_back(self, node):
        if node.isleaf == False:
            left_info = self.trace_back(node.left)
            right_info = self.trace_back(node.right)
            [C_l, N_l] = left_info
            [C_r, N_r] = right_info
            C = np.multiply(C_l, N_1) + np.multiply(C_r, N_r)
            N = N_l + N_r
            node.info = [C, N]
            return node.info
        else:
            return node.info

# %%
tt = KDtree(5000, Djoined)
Djoined.to_csv('labeled_stations.csv')
# Out:
# -----Leaf----- 3482.0 ----Nodes---- 165
# -----Leaf----- 3381.0 ----Nodes---- 132
# -----Leaf----- 3431.0 ----Nodes---- 104
# -----Leaf----- 3337.0 ----Nodes---- 108
# -----Leaf----- 3454.0 ----Nodes---- 90
# -----Leaf----- 3349.0 ----Nodes---- 96
# -----Leaf----- 3416.0 ----Nodes---- 97
# -----Leaf----- 3386.0 ----Nodes---- 97
# -----Leaf-----
#  3425.0 ----Nodes---- 104
# -----Leaf----- 3376.0 ----Nodes---- 104
# -----Leaf----- 3404.0 ----Nodes---- 117
# -----Leaf----- 3393.0 ----Nodes---- 118
# -----Leaf----- 3412.0 ----Nodes---- 107
# -----Leaf----- 3391.0 ----Nodes---- 110
# -----Leaf----- 3403.0 ----Nodes---- 128
# -----Leaf----- 3351.0 ----Nodes---- 106
# -----Leaf-----
#  3425.0 ----Nodes---- 93
# -----Leaf----- 3412.0 ----Nodes---- 97
# -----Leaf----- 3417.0 ----Nodes---- 97
# -----Leaf----- 3394.0 ----Nodes---- 86
# -----Leaf----- 3434.0 ----Nodes---- 102
# -----Leaf----- 3422.0 ----Nodes---- 99
# -----Leaf----- 3386.0 ----Nodes---- 119
# ...

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

stations = station_info
lons=Djoined.ix[:,'longitude'].values
lats=Djoined.ix[:,'latitude'].values
ll=len(lons)
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
select=(lons>lonmin) * (lons<lonmax)*(lats>latsmin)*(lats<latsmax)


plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,\
            llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
#m.fillcontinents(color='coral',lake_color='aqua')

parallels = np.arange(-80,81,10.)
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(10.,351.,20.)
m.drawmeridians(meridians,labels=[True,False,False,True])

#m.drawmapboundary(fill_color='aqua')

colors = Djoined['label'].tolist()
x, y = m(lons,lats)
col = m.scatter(x,y,c=colors, marker='o',lw=0,zorder=2,s=3)
colbar = m.colorbar(col, location='right', pad = "5%")
plt.title('weather stations')
plt.show()

# %%
PCA

mapper:
    station => key
    x = x - mean
    data => [key, x*x^T]
reducer:
    1/n sum x*x^T
    PCA cov matrix

# %%
Djoined.head()
# Out:
#            station  weight  latitude  longitude  elevation  label
# 6940   AYW00090001      38  -90.0000     0.0000     -999.9   4802
# 10403  AYW00068201      13  -80.0167  -119.5333     1543.2   5646
# 23779  AYW00077401       3  -79.4667    40.5833     3505.2    328
# 20510  AYW00067601       3  -78.2000  -162.2500       32.0   6087
# 20508  AY000896640      41  -77.8833   166.7333       24.1   2152
#
# [5 rows x 6 columns]

# %%
# %%writefile tttt.py
import re,pickle,base64,zlib
from mrjob.job import MRJob
import pandas as pd
import numpy as np
import sklearn as sk
import random

Djoined = pd.DataFrame.from_csv('labeled_stations.csv')

class PCA_weather(MRJob):

    def mapper(self, _, line):
        elements = line.split(',')
        find_ind = Djoined[Djoined['station'] == elements[0]]
        #if len(find_ind) != 0 and (elements[1] == 'TMAX' or elements[1] == 'TMIN'):
        if len(find_ind) != 0 and elements[1] == 'TMAX':
            ind = find_ind.index[0]
            region = Djoined.loc[ind]['label']
            #region = random.randint(0,9)   
            df = pd.DataFrame(elements[3:])
            df[0][df[0] == ''] = float('NaN')
            df[0]=df[0].astype(float)
            mean = np.mean(df[0].transpose())
            row = df[0] - mean
            outer = np.outer(row, row).tolist()
            yield region, outer
    
    def reducer(self, region, matrixs):
        matrixs = list(matrixs)
        C = np.zeros(np.shape(matrixs[0]))
        N = np.zeros(np.shape(matrixs[0]))
        for matrix in matrixs:
            outer = np.array(matrix)
            valid = np.isnan(outer) == False
            C[valid] = C[valid] + outer[valid]
            N[valid] = N[valid] + 1    
        valid_outer = np.multiply(1, N>0)
        cov = np.divide(C, N)
        cov = np.multiply(cov, valid_outer)
        U, D, V = np.linalg.svd(cov)
        cum_sum = np.cumsum(D[:])/sum(D)
        for i in range(len(cum_sum)):
            if cum_sum[i] >= 0.95:
                ind = i 
                break
        yield region, ind
        #yield region, [ind, U.tolist(), C.tolist(), N.tolist()]

if __name__ == '__main__':
    PCA_weather.run()
# Out:
# Overwriting tttt.py

# %%
local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
# !python tttt.py $local_data
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/tttt.ubuntu.20140522.204338.882332
# writing to /tmp/tttt.ubuntu.20140522.204338.882332/step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /tmp/tttt.ubuntu.20140522.204338.882332/step-0-mapper-sorted
# > sort /tmp/tttt.ubuntu.20140522.204338.882332/step-0-mapper_part-00000
# writing to /tmp/tttt.ubuntu.20140522.204338.882332/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# Moving /tmp/tttt.ubuntu.20140522.204338.882332/step-0-reducer_part-00000 -> /tmp/tttt.ubuntu.20140522.204338.882332/output/part-00000
# Streaming final output from /tmp/tttt.ubuntu.20140522.204338.882332/output
# 1313.0	17
# 5094.0	36
# 5993.0	25
# 8312.0	23
# removing tmp directory /tmp/tttt.ubuntu.20140522.204338.882332

# %%
# !python tttt.py -r emr --emr-job-flow-id  $job_flow_id < $local_data
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/tttt.ubuntu.20140522.204629.218855
# reading from STDIN
# Copying non-input files into s3://chuan.bucket/scratch/tttt.ubuntu.20140522.204629.218855/files/
# Adding our job to existing job flow j-1RE8D7HBISOI0
# Job launched 30.8s ago, status RUNNING: Running step (tttt.ubuntu.20140522.204629.218855: Step 1 of 1)
# Job launched 61.6s ago, status RUNNING: Running step (tttt.ubuntu.20140522.204629.218855: Step 1 of 1)
# Job launched 92.5s ago, status RUNNING: Running step (tttt.ubuntu.20140522.204629.218855: Step 1 of 1)
# Job launched 123.4s ago, status RUNNING: Running step (tttt.ubuntu.20140522.204629.218855: Step 1 of 1)
# Job on job flow j-1RE8D7HBISOI0 failed with status WAITING: Waiting after step failed
# Logs are in s3://yoav.hadoop/log/j-1RE8D7HBISOI0/
# ec2_key_pair_file not specified, going to S3
# Scanning S3 logs for probable cause of failure
# Waiting 5.0s for S3 eventual consistency
# ...

# %%
# !python tttt.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv > number_eigen.txt

# %%
suppose you want the median of a very large data, sample n points take that median
Glivenko Cantelli theorem
